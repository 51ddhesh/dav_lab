# %% [markdown]
# #### Siddhesh Badnapurkar
# #### RBT23CB016

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("amazonSalesReport.csv", low_memory=False)

# %%
print("Dataset Info:")
data.info()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
data.fillna(0, inplace = True)

# %%
data['Amount'] = pd.to_datetime(data['Amount'])

# %%
print("Cleaned Data:")
data.head()
# Out:
# Cleaned Data:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency                        Amount    ship-city  \
# ...

# %% [markdown]
# ### Part 2

# %%
df = pd.read_csv("ecommerce_sales_data.csv")

# %%
customer_analysis = df.groupby('Customer_ID')['Total_Sales'].sum().sort_values(ascending=False)

# %%
print("Top 10 Customers by Sale:")
customer_analysis.head(10)
# Out:
# Top 10 Customers by Sale:
# Customer_ID
# 59fedcf1-59a3-427b-87c1-12d109a689d6    9999.4
# 337db941-81be-4bd7-8003-e867c6e28a5b    9999.1
# 05940bfc-3072-43dd-959a-f961a9f4cbf8    9998.7
# 1d9b1f44-e605-42ad-ad9c-a117f87a4d13    9998.3
# 84762f6f-61a1-46b9-b651-d8e310849f6a    9997.6
# 70e1fec2-a70f-4eeb-9c95-67151081d515    9996.5
# 84f3a49b-79d5-41b8-981e-d365acfef1d6    9996.2
# 1b762225-4362-46ef-9cfb-2509f8cd18f9    9996.1
# f1ea6bc6-e38e-4db7-a019-87bf04b9a3db    9995.8
# 10da6c99-d1dd-48db-a2f4-3e99d3dbc38d    9993.8
# Name: Total_Sales, dtype: float64

# %%
customer_frequency = df['Customer_ID'].value_counts()

# %%
print("\nTop 10 Customers by Purchase Frequency:")
customer_frequency.head(10)
# Out:
# Top 10 Customers by Purchase Frequency:
# Customer_ID
# 583b4435-673e-40e9-a2eb-51497b9f96cb    1
# e3d66fee-a4bf-40f6-9d52-4193298808ee    1
# 03a5c591-98c8-4610-b2eb-1ce89e19b4eb    1
# 7d83b984-1312-4e76-a088-3ea2814c4251    1
# 1d2b4e7b-0b20-4248-a0bd-1e3be380d8d7    1
# 75e19ba8-083a-4bd5-b323-949b44ca1b80    1
# 2bc9d8bc-a9fb-4000-b325-c265800e5bd8    1
# acb9a768-2c10-4bfc-976f-6981a2c0c269    1
# f5f94b4e-683f-41d4-8f70-f039a48cb655    1
# a27d5efc-afdb-47f3-b939-bdad33548ec4    1
# Name: count, dtype: int64

# %% [markdown]
# ### Part 3

# %%
product_sales = df.groupby('Product_Name')['Total_Sales'].sum().sort_values(ascending=False)

# %%
print("Top 10 Products by Sales:")
product_sales.head(10)
# Out:
# Top 10 Products by Sales:
# Product_Name
# fill       433158.60
# account    431246.57
# perhaps    427055.75
# her        425532.61
# media      422558.40
# spring     417047.65
# half       415513.13
# two        412043.32
# reveal     410452.91
# focus      406148.49
# Name: Total_Sales, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
top_products = product_sales.head(10)

# %%
top_products.plot(kind='bar', color='skyblue', figsize=(10, 6))
plt.title("Top 10 Products by Sales")
plt.xlabel("Product Name")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Part 4

# %%
df['Purchase Date'] = pd.to_datetime(df['Purchase Date'])
# Out:
# /tmp/ipykernel_5436/3081094146.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Purchase Date'] = pd.to_datetime(df['Purchase Date'])

# %%
df['Month'] = df['Purchase Date'].dt.to_period('M')

# %%
df.to_csv("temp.csv")

# %%
monthly_sales = df.groupby('Month')['Total_Sales'].sum()

# %%
monthly_sales.plot(kind='line', figsize=(10, 6), marker='o')
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.grid()
plt.show()

# %% [markdown]
# ### Part 5

# %%
df = pd.read_csv("amazonSalesReport.csv")
# Out:
# /tmp/ipykernel_5436/14139339.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("amazonSalesReport.csv")

# %%
region_sales = df.groupby('ship-state')['Amount'].sum().sort_values(ascending=False)
print("Sales by Region:")
print(region_sales)
# Out:
# Sales by Region:
# ship-state
# MAHARASHTRA      13335534.14
# KARNATAKA        10481114.37
# TELANGANA         6916615.65
# UTTAR PRADESH     6816642.08
# TAMIL NADU        6515650.11
#                     ...
# rajsthan              521.00
# AR                    493.00
# Rajsthan              443.00
# PB                    399.00
# APO                     0.00
# Name: Amount, Length: 69, dtype: float64

# %%
region_sales.plot(kind='pie', autopct='%1.1f%%', figsize=(8, 8), startangle=90, colors=['skyblue', 'orange', 'lightgreen'])
plt.title("Sales Distribution by Region")
plt.ylabel("")
plt.show()

# %% [markdown]
# ### Part 6

# %%
print("Insights:")
print("- Top customers contribute significantly to total revenue. Target them with loyalty programs.")
print("- High-performing products dominate sales. Consider increasing inventory for these products.")
print("- Seasonal trends indicate peak sales during certain months. Optimize marketing during these periods.")
print("- Regions with lower sales could benefit from targeted campaigns.")
# Out:
# Insights:
# - Top customers contribute significantly to total revenue. Target them with loyalty programs.
# - High-performing products dominate sales. Consider increasing inventory for these products.
# - Seasonal trends indicate peak sales during certain months. Optimize marketing during these periods.
# - Regions with lower sales could benefit from targeted campaigns.
