# %% [markdown]
# #### Siddhesh Badnapurkar
# #### RBT23CB016

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, kurtosis

# %%
path = 'Heart.csv'
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %%
df.describe()
# Out:
#        Unnamed: 0         Age         Sex      RestBP        Chol         Fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean   152.000000   54.438944    0.679868  131.689769  246.693069    0.148515
# std     87.612784    9.038662    0.467299   17.599748   51.776918    0.356198
# min      1.000000   29.000000    0.000000   94.000000  126.000000    0.000000
# 25%     76.500000   48.000000    0.000000  120.000000  211.000000    0.000000
# 50%    152.000000   56.000000    1.000000  130.000000  241.000000    0.000000
# 75%    227.500000   61.000000    1.000000  140.000000  275.000000    0.000000
# max    303.000000   77.000000    1.000000  200.000000  564.000000    1.000000
#
#           RestECG       MaxHR       ExAng     Oldpeak       Slope          Ca
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# std      0.994971   22.875003    0.469794    1.161075    0.616226    0.937438
# min      0.000000   71.000000    0.000000    0.000000    1.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    2.000000    0.000000
# 75%      2.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    3.000000    3.000000

# %%
for column in df.select_dtypes(include = np.number).columns:
    print(f'Statistics for {column}:')
    print(f'Mean: {df[column].mean()}')
    print(f'Median: {df[column].median()}')
    print(f'Variance: {df[column].var()}')
    print(f'Standard Deviation: {df[column].std()}')
    print(f'Skewness: {df[column].skew()}')
    print(f'Kurtosis: {df[column].kurtosis}')
    print()
# Out:
# Statistics for Unnamed: 0:
# Mean: 152.0
# Median: 152.0
# Variance: 7676.0
# Standard Deviation: 87.61278445523804
# Skewness: 0.0
# Kurtosis: <bound method Series.kurt of 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 298    299
# 299    300
# 300    301
# 301    302
# 302    303
# Name: Unnamed: 0, Length: 303, dtype: int64>
#
# Statistics for Age:
# Mean: 54.43894389438944
# Median: 56.0
# Variance: 81.69741874849731
# Standard Deviation: 9.038662442446743
# Skewness: -0.20906046882012877
# Kurtosis: <bound method Series.kurt of 0      63
# 1      67
# 2      67
# 3      37
# 4      41
#        ..
# 298    45
# 299    68
# 300    57
# 301    57
# 302    38
# Name: Age, Length: 303, dtype: int64>
#
# Statistics for Sex:
# Mean: 0.6798679867986799
# Median: 1.0
# Variance: 0.21836819443533886
# Standard Deviation: 0.4672988277701313
# Skewness: -0.77493506152194
# Kurtosis: <bound method Series.kurt of 0      1
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 298    1
# 299    1
# 300    1
# 301    0
# 302    1
# Name: Sex, Length: 303, dtype: int64>
#
# Statistics for RestBP:
# Mean: 131.68976897689768
# Median: 130.0
# Variance: 309.751120145127
# Standard Deviation: 17.599747729587687
# Skewness: 0.7060346498131783
# Kurtosis: <bound method Series.kurt of 0      145
# 1      160
# 2      120
# 3      130
# 4      130
#       ...
# 298    110
# 299    144
# 300    130
# 301    130
# 302    138
# Name: RestBP, Length: 303, dtype: int64>
#
# Statistics for Chol:
# Mean: 246.69306930693068
# Median: 241.0
# Variance: 2680.8491902170326
# Standard Deviation: 51.776917542637015
# Skewness: 1.1355031533363453
# Kurtosis: <bound method Series.kurt of 0      233
# 1      286
# 2      229
# 3      250
# 4      204
#       ...
# 298    264
# 299    193
# 300    131
# 301    236
# 302    175
# Name: Chol, Length: 303, dtype: int64>
#
# Statistics for Fbs:
# Mean: 0.1485148514851485
# Median: 0.0
# Variance: 0.126876926103206
# Standard Deviation: 0.35619787492797594
# Skewness: 1.9866519309144517
# Kurtosis: <bound method Series.kurt of 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 298    0
# 299    1
# 300    0
# 301    0
# 302    0
# Name: Fbs, Length: 303, dtype: int64>
#
# Statistics for RestECG:
# Mean: 0.9900990099009901
# Median: 1.0
# Variance: 0.9899678709592841
# Standard Deviation: 0.9949712915251797
# Skewness: 0.01990027945947886
# Kurtosis: <bound method Series.kurt of 0      2
# 1      2
# 2      2
# 3      0
# 4      2
#       ..
# 298    0
# 299    0
# 300    0
# 301    2
# 302    0
# Name: RestECG, Length: 303, dtype: int64>
#
# Statistics for MaxHR:
# Mean: 149.6072607260726
# Median: 153.0
# Variance: 523.2657749218629
# Standard Deviation: 22.875003276980376
# Skewness: -0.5374486699106463
# Kurtosis: <bound method Series.kurt of 0      150
# 1      108
# 2      129
# 3      187
# 4      172
#       ...
# 298    132
# 299    141
# 300    115
# 301    174
# 302    173
# Name: MaxHR, Length: 303, dtype: int64>
#
# Statistics for ExAng:
# Mean: 0.32673267326732675
# Median: 0.0
# Variance: 0.2207068388958107
# Standard Deviation: 0.46979446452231716
# Skewness: 0.7425315444212831
# Kurtosis: <bound method Series.kurt of 0      0
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 298    0
# 299    0
# 300    1
# 301    0
# 302    0
# Name: ExAng, Length: 303, dtype: int64>
#
# Statistics for Oldpeak:
# Mean: 1.0396039603960396
# Median: 0.8
# Variance: 1.3480952068716792
# Standard Deviation: 1.161075022068634
# Skewness: 1.2697199306019966
# Kurtosis: <bound method Series.kurt of 0      2.3
# 1      1.5
# 2      2.6
# 3      3.5
# 4      1.4
#       ...
# 298    1.2
# 299    3.4
# 300    1.2
# 301    0.0
# 302    0.0
# Name: Oldpeak, Length: 303, dtype: float64>
#
# Statistics for Slope:
# Mean: 1.6006600660066006
# Median: 2.0
# Variance: 0.3797346622079435
# Standard Deviation: 0.6162261453459627
# Skewness: 0.5083156098165441
# Kurtosis: <bound method Series.kurt of 0      3
# 1      2
# 2      2
# 3      3
# 4      1
#       ..
# 298    2
# 299    2
# 300    2
# 301    2
# 302    1
# Name: Slope, Length: 303, dtype: int64>
#
# Statistics for Ca:
# Mean: 0.6722408026755853
# Median: 0.0
# Variance: 0.8787905995376076
# Standard Deviation: 0.9374383177242157
# Skewness: 1.189352105415407
# Kurtosis: <bound method Series.kurt of 0      0.0
# 1      3.0
# 2      2.0
# 3      0.0
# 4      0.0
#       ...
# 298    0.0
# 299    2.0
# 300    1.0
# 301    1.0
# 302    NaN
# Name: Ca, Length: 303, dtype: float64>

# %%
print('Correlation Matrix')
numeric_data = df.select_dtypes(include = np.number)
correlation_matrix = numeric_data.corr()
correlation_matrix
# Out:
# Correlation Matrix
#             Unnamed: 0       Age       Sex    RestBP      Chol       Fbs  \
# Unnamed: 0    1.000000 -0.002367 -0.070849 -0.022028 -0.095518 -0.039471
# Age          -0.002367  1.000000 -0.097542  0.284946  0.208950  0.118530
# Sex          -0.070849 -0.097542  1.000000 -0.064456 -0.199915  0.047862
# RestBP       -0.022028  0.284946 -0.064456  1.000000  0.130120  0.175340
# Chol         -0.095518  0.208950 -0.199915  0.130120  1.000000  0.009841
# Fbs          -0.039471  0.118530  0.047862  0.175340  0.009841  1.000000
# RestECG      -0.150232  0.148868  0.021647  0.146560  0.171043  0.069564
# MaxHR        -0.105488 -0.393806 -0.048663 -0.045351 -0.003432 -0.007854
# ExAng        -0.000402  0.091661  0.146201  0.064762  0.061310  0.025665
# Oldpeak      -0.120384  0.203805  0.102173  0.189171  0.046564  0.005747
# Slope        -0.028458  0.161770  0.037533  0.117382 -0.004062  0.059894
# Ca            0.046938  0.362605  0.093185  0.098773  0.119000  0.145478
#
#              RestECG     MaxHR     ExAng   Oldpeak     Slope        Ca
# Unnamed: 0 -0.150232 -0.105488 -0.000402 -0.120384 -0.028458  0.046938
# Age         0.148868 -0.393806  0.091661  0.203805  0.161770  0.362605
# Sex         0.021647 -0.048663  0.146201  0.102173  0.037533  0.093185
# RestBP      0.146560 -0.045351  0.064762  0.189171  0.117382  0.098773
# Chol        0.171043 -0.003432  0.061310  0.046564 -0.004062  0.119000
# Fbs         0.069564 -0.007854  0.025665  0.005747  0.059894  0.145478
# RestECG     1.000000 -0.083389  0.084867  0.114133  0.133946  0.128343
# MaxHR      -0.083389  1.000000 -0.378103 -0.343085 -0.385601 -0.264246
# ExAng       0.084867 -0.378103  1.000000  0.288223  0.257748  0.145570
# Oldpeak     0.114133 -0.343085  0.288223  1.000000  0.577537  0.295832
# Slope       0.133946 -0.385601  0.257748  0.577537  1.000000  0.110119
# Ca          0.128343 -0.264246  0.145570  0.295832  0.110119  1.000000

# %%
plt.figure(figsize = (10, 8))
sns.heatmap(correlation_matrix, annot = True, cmap = 'coolwarm', fmt = '.2f')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
columns_to_plot = df.select_dtypes(include = np.number).columns
plt.figure(figsize = (10, 6))
for column in columns_to_plot:
    plt.plot(df.index, df[column], label = column)
plt.title('Line Plot')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend()
plt.grid()
plt.show()

# %%
means = df[columns_to_plot].mean()
means.plot(kind = 'bar', color = 'skyblue', figsize = (8, 6))
plt.title('Bar plot of Mean Values')
plt.xlabel('Columns')
plt.ylabel('Mean')
plt.show()

# %%
for column in columns_to_plot:
    plt.figure(figsize = (8, 6))
    plt.hist(df[column], bins = 15, color = 'orange', edgecolor = 'black')
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('frequency')
    plt.show()
    print()

# %%
if len(columns_to_plot) >= 2:
    plt.figure(figsize = (8, 6))
    plt.scatter(df[columns_to_plot[0]], df[columns_to_plot[1]], color = 'green', alpha = 0.6)
    plt.title(f'Scatter Plot of {columns_to_plot[0]} vs {columns_to_plot[1]}')
    plt.xlabel(columns_to_plot[0])
    plt.ylabel(columns_to_plot[1])
    plt.grid()
    plt.show()
